# %% [markdown]
# ## Results
#
# ## Expected results
#
# | Item |     Total |
# | ---- | --------: |
# | TC1  |   2481.86 |
# | TC2  | 166568.23 |
# | TC3  | 165235.37 |

# %%
# !uv run python compute_sales.py test_files/TC1/TC1.ProductList.json test_files/TC1/TC1.Sales.json
# Out:
# ============================================================
# RESULTS
#
# Total Sales: $2,481.86
# Execution Time: 0.0081 seconds
#
#
# Results have been saved to SalesResults.txt

# %%
# !uv run python compute_sales.py test_files/TC1/TC1.ProductList.json test_files/TC2/TC2.Sales.json
# Out:
# ============================================================
# RESULTS
#
# Total Sales: $166,568.23
# Execution Time: 0.0087 seconds
#
#
# Results have been saved to SalesResults.txt
